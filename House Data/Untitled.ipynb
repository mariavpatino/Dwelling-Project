# %%
import pandas as pd

# %%
url = '/Users/omarkreidieh/Documents/GitHub/Dwelling-Project/House Data/houses_df.csv'
data = pd.read_csv(url)
data['Zip Code'] = data['Zip Code'].apply(lambda x: str(x).zfill(5))

# %%
data['full_address'] = data['Address'] + ' '+ data['Zip Code'] + ' ' + 'USA'

# %%
import requests
import json

def geo_map_lat(address):
    GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAe6xOpt5VyUzsdDicBFV0orq9JVyZ_3p8'
    params = {
            'address': str(address),
            'sensor': 'false'
        }
    req = requests.get(GOOGLE_MAPS_API_URL, params=params)
    res = req.json()
    #Use the first result
    result = res['results'][0]

    #geodata = dict()
    #geodata['lat'] = result['geometry']['location']['lat']
    #geodata['lng'] = result['geometry']['location']['lng']
    #geodata['address'] = result['formatted_address']

    print(result['geometry']['location']['lat'])

        # Do the request and get the response data

# %%
data['full_address'].apply(lambda x: geo_map_lat(x))
# Out:
# 40.66369479999999
# 40.6556021
# 40.648171
# 40.6780289
# 40.6476492
# 40.6649029
# 40.6762579
# 40.677257
# 40.658801
# 40.8105048
# 40.8106961
# 40.8049221
# 40.817424
# 40.777001
# 40.7875799
# 40.821378
# 40.794754
# 40.7950052
# 40.7779837
# 40.8105048
# 40.8106961
# 40.8049221
# 40.817424
# 40.777001
# 40.7875799
# 40.821378
# 40.794754
# 40.7950052
# 40.7779837
# 40.8105048
# 40.8106961
# 40.8049221
# 40.817424
# 40.777001
# 40.7875799
# 40.821378
# 40.794754
# 40.7950052
# 40.7779837
# 40.8105048
# 40.8106961
# 40.8049221
# 40.817424
# 40.777001
# 40.7875799
# 40.821378
# 40.794754
# 40.7950052
# 40.7779837
# 40.8105048
# 40.8106961
# 40.8049221
# 40.817424
# 40.777001
# 40.7875799
# 40.821378
# 40.794754
# 40.7950052
# 40.7779837
# 40.8105048
# 40.8106961
# 40.8049221
# 40.817424
# 40.777001
# 40.7875799
# 40.821378
# 40.794754
# 40.7950052
# 40.7779837
# 40.878796
# 40.8857907
# 40.87647219999999
# 40.87647219999999
# 40.87647219999999
# 40.87647219999999
# ...

# %%
data
# Out:
#                                                 Address  \
# 0                         116 West 19th Street, Bayonne
# 1                            17  Hartley Place, Bayonne
# 2                           84 West 3rd Street, Bayonne
# 3                          20 East 43rd Street, Bayonne
# 4                             62-64  Broadway , Bayonne
# 5                         147  Prospect Avenue, Bayonne
# 6                900  John F Kennedy Boulevard, Bayonne
# 7                        33  Roosevelt Terrace, Bayonne
# 8                          894-896  Boulevard , Bayonne
# 9               324  Hoover Avenue, Unit 71, Bloomfield
# 10              316  Hoover Avenue, Unit 54, Bloomfield
# 11                       22  Osborne Street, Bloomfield
# 12                        720  Broad Street, Bloomfield
# 13                        120  Floyd Avenue, Bloomfield
# 14            159  Franklin Street, Unit 29, Bloomfield
# 15                         81  Dewey Street, Bloomfield
# ...
